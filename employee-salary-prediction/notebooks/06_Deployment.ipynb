# %%
import pandas as pd
import joblib

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("../data/processed/cleaned_salary.csv")

# %%
X = df.drop("Salary", axis=1)

y = df["Salary"]

# %%
numerical_features = [
    "Age",
    "Years of Experience"
]

categorical_features = [
    "Gender",
    "Education Level",
    "Job Title"
]

# %%
preprocessor = ColumnTransformer(
    transformers=[
        (
            "num",
            StandardScaler(),
            numerical_features
        ),
        (
            "cat",
            OneHotEncoder(handle_unknown="ignore"),
            categorical_features
        )
    ]
)

# %%
pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("model", LinearRegression())
    ]
)

# %%
pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Age',
#                                                    'Years of Experience']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Gender', 'Education Level',
#                                                    'Job Title'])])),
#                 ('model', LinearRegression())])

# %%
joblib.dump(
    pipeline,
    "../models/salary_model.pkl"
)
# Out:
# ['../models/salary_model.pkl']

# %%
loaded_pipeline = joblib.load("../models/salary_model.pkl")

# %%
new_employee = pd.DataFrame(
    {
        "Age": [30],
        "Gender": ["Male"],
        "Education Level": ["Master's Degree"],
        "Job Title": ["Data Scientist"],
        "Years of Experience": [5],
    }
)

# %%
new_employee
# Out:
#    Age Gender  Education Level       Job Title  Years of Experience
# 0   30   Male  Master's Degree  Data Scientist                    5

# %%
prediction = loaded_pipeline.predict(new_employee)

# %%
prediction
# Out:
# array([133347.60513913])

# %%
print(f"Predicted Salary: ${prediction[0]:,.2f}")
# Out:
# Predicted Salary: $133,347.61
